# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_randomization import *

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('perceptron_citation_cleaned_lcc.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 3149

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 6.697681803747221
# 4.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.5792701677027216
# approx_average_clustering_coefficient: 0.25639534697779187
# degree_entropy: 2.837728819184851
#
#
# Randomization parameter p=0.25
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.46581774610976323
# approx_average_clustering_coefficient: 0.07243110275224118
# degree_entropy: 2.803242399534177
#
#
# Randomization parameter p=0.5
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.35814198296516636
# approx_average_clustering_coefficient: 0.021016526595010035
# degree_entropy: 2.6824994265405007
#
#
# Randomization parameter p=0.75
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.2699929695690734
# approx_average_clustering_coefficient: 0.005197989348502061
# degree_entropy: 2.5241861607096956
#
#
# Randomization parameter p=1
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.21577037392698906
# approx_average_clustering_coefficient: 0.002024084733988308
# degree_entropy: 2.3522984950542734

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('pepticulcer_citation_cleaned_lcc.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 19539

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 13.547162086084242
# 5.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.6517972196282894
# approx_average_clustering_coefficient: 0.2230842116209337
# degree_entropy: 3.43302565826567
#
#
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.5075212567156272
# approx_average_clustering_coefficient: 0.052438749455574786
# degree_entropy: 3.387767505722877
#
#
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.36834388300926846
# approx_average_clustering_coefficient: 0.015472889769468626
# degree_entropy: 3.2487935735730673
#
#
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.23990101628171873
# approx_average_clustering_coefficient: 0.003119004484537157
# degree_entropy: 3.015984954537072
#
#
# Randomization parameter p=1
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.15178714583427655
# approx_average_clustering_coefficient: 0.0006945758412266999
# degree_entropy: 2.710191620244661
