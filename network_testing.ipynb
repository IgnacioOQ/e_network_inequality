# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_randomization import *

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('perceptron_citation_cleaned_lcc.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 3149

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 6.697681803747221
# 4.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  print(stats)
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.5792701677027214, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(2.837728819184851)}
# 6.697681803747221
# 4.0
# Randomization parameter p=0.25
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.46457595877496094, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(2.796013350040255)}
# 6.697681803747221
# 5.0
# Randomization parameter p=0.5
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.36257534172075534, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(2.681688016197434)}
# 6.697681803747221
# 5.0
# Randomization parameter p=0.75
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.2656344426763011, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(2.5114372863079555)}
# 6.697681803747221
# 6.0
# Randomization parameter p=1
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.21317140461017559, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(2.3386643172878006)}
# 6.697681803747221
# 7.0

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('pepticulcer_citation_cleaned_lcc.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 19539

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 13.547162086084242
# 5.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  print(stats)
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.6517972196282893, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(3.43302565826567)}
# 13.547162086084242
# 5.0
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.5083882476338268, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(3.3896922047640734)}
# 13.547162086084242
# 8.0
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.36900512537106267, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(3.2465138974311003)}
# 13.547162086084242
# 10.0
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.24047620959863014, 'approx_average_clustering_coefficient': 0, 'diameter': 0, 'degree_entropy': np.float64(3.0174852243631936)}
# 13.547162086084242
# 12.0
