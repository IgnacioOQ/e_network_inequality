# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_randomization import *

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('perceptron_citation_cleaned_lcc.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 3149

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 6.697681803747221
# 4.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  print(stats)
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.5792701677027214, 'approx_average_clustering_coefficient': 0.25639534697779187, 'diameter': 0, 'degree_entropy': np.float64(2.837728819184851)}
# 6.697681803747221
# 4.0
# Randomization parameter p=0.25
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.46720242164942083, 'approx_average_clustering_coefficient': 0.07544701657844012, 'diameter': 0, 'degree_entropy': np.float64(2.791791935585501)}
# 6.697681803747221
# 5.0
# Randomization parameter p=0.5
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.36921255153479904, 'approx_average_clustering_coefficient': 0.02199592905992275, 'diameter': 0, 'degree_entropy': np.float64(2.7139795945336536)}
# 6.697681803747221
# 6.0
# Randomization parameter p=0.75
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.26588655227610136, 'approx_average_clustering_coefficient': 0.0052056735922132, 'diameter': 0, 'degree_entropy': np.float64(2.503509151372092)}
# 6.697681803747221
# 6.0
# Randomization parameter p=1
# {'average_degree': 6.697681803747221, 'degree_gini_coefficient': 0.21782049594734265, 'approx_average_clustering_coefficient': 0.0020501772094703753, 'diameter': 0, 'degree_entropy': np.float64(2.361402410799697)}
# 6.697681803747221
# 7.0

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('pepticulcer_citation_cleaned_lcc.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 19539

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 13.547162086084242
# 5.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  print(stats)
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.6517972196282893, 'approx_average_clustering_coefficient': 0.2230842116209337, 'diameter': 0, 'degree_entropy': np.float64(3.43302565826567)}
# 13.547162086084242
# 5.0
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.5074076462219941, 'approx_average_clustering_coefficient': 0.053019836089471695, 'diameter': 0, 'degree_entropy': np.float64(3.3867123355216697)}
# 13.547162086084242
# 8.0
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.3659114116242912, 'approx_average_clustering_coefficient': 0.015457322504126285, 'diameter': 0, 'degree_entropy': np.float64(3.2371272030177343)}
# 13.547162086084242
# 10.0
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# {'average_degree': 13.547162086084242, 'degree_gini_coefficient': 0.23972848972556005, 'approx_average_clustering_coefficient': 0.0030784601100641153, 'diameter': 0, 'degree_entropy': np.float64(3.0241926006105633)}
# 13.547162086084242
# 12.0
